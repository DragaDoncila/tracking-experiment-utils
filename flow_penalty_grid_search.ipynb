# %%
import pandas as pd
baseline_root = '/home/ddon0001/PhD/experiments/scaled/no_div_constraint'
ds_summary = pd.read_csv(f'{baseline_root}/summary.csv')

# %%
import numpy as np

search_space = np.linspace(20, 1000, 50)
search_space
# Out:
# array([  20.,   40.,   60.,   80.,  100.,  120.,  140.,  160.,  180.,
#         200.,  220.,  240.,  260.,  280.,  300.,  320.,  340.,  360.,
#         380.,  400.,  420.,  440.,  460.,  480.,  500.,  520.,  540.,
#         560.,  580.,  600.,  620.,  640.,  660.,  680.,  700.,  720.,
#         740.,  760.,  780.,  800.,  820.,  840.,  860.,  880.,  900.,
#         920.,  940.,  960.,  980., 1000.])

# %%
import json
import os
import time
from generate_configs import get_config_for_row

out_root = '/home/ddon0001/PhD/experiments/flow_penalty_grid/'
for _, row in ds_summary.iterrows():
    ds_name = row['ds_name']
    metrics_pth = os.path.join(baseline_root, ds_name, 'metrics.json')
    with open(metrics_pth, 'r') as f:
        metrics = json.load(f)
        baseline_metric = metrics['AOGM']
    last_best = baseline_metric
    for penalty in search_space:
        # load config
        config = get_config_for_row(
            row,
            out_root,
            div_constraint=False,
            penalize_flow=True,
            flow_penalty=penalty
        )
        # solve
        start = time.time()
        tracked = config.run(write_out=False)
        # evaluate
        results, matched = config.evaluate(tracked.tracked_detections, tracked.tracked_edges, write_out=False)
        # is it better than baseline?
        if results['AOGM'] < last_best:
            print(f'Found improvement for {ds_name} with penalty {penalty}')
            last_best = results['AOGM']
            # save config, results, matched
            config.data_config.dataset_name = f'{ds_name}_{penalty}'
            config.write_solved(tracked, start)
            config.write_metrics(results, matched)
# Out:
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2371.12it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.40230607986450195 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.26it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 50.38it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.35it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 670401.05it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 353145.91it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 524684.29it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2158.37it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.2948634624481201 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.27it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 50.00it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.37it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 742036.65it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 341973.86it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 523892.31it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2539.62it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.29065608978271484 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.89it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 50.26it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.44it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 624078.30it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 341446.94it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 514762.56it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2434.82it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.37674498558044434 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.41it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 49.63it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.30it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 695090.04it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 338491.44it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 485424.69it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2288.56it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.2950761318206787 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.44it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 49.76it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.30it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 710521.58it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 331983.61it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 526874.62it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2310.10it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.37699103355407715 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 43.66it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 49.97it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.98it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 687944.25it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 345349.19it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 528680.36it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2481.84it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.2963850498199463 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.40it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.00it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.54it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 694106.89it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 338061.12it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 517448.61it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2483.04it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3020162582397461 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.01it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.35it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.47it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 663751.44it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 328781.99it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 522512.09it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2482.24it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3854999542236328 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.40it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.35it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.57it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 608347.40it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 313953.81it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 503559.89it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2481.44it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.301098108291626 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.60it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.33it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.28it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 646836.86it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 342502.41it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 530093.40it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2415.06it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.38746094703674316 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.67it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.13it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.46it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 694434.29it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 342414.21it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 495119.34it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2416.96it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3013901710510254 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.86it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.35it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.37it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 635939.83it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 338405.29it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 473665.86it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2464.08it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.39241623878479004 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.09it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.46it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.44it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 631574.73it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 319998.64it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 472698.20it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2473.59it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3006470203399658 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.20it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.04it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.37it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 667362.06it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 350723.92it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 533556.73it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2355.39it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30295395851135254 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.06it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.43it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.53it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 697394.93it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 306217.04it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 417663.85it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2481.17it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.38950490951538086 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.90it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.20it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.42it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 603608.32it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 329678.74it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 492659.55it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2475.45it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30448436737060547 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.04it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.94it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.12it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 587704.87it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 330169.94it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 510785.37it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2182.16it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30872082710266113 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 34.95it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.54it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.90it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 635390.90it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 336095.64it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 490051.05it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2414.18it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30536866188049316 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.64it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.65it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.02it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 618052.35it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 314920.50it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 477740.75it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2419.49it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30560994148254395 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.56it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 49.16it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.01it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 708129.25it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 302937.88it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 480053.47it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2474.65it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.39540958404541016 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.27it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.70it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.97it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 616499.46it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 310652.89it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 501558.75it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2404.11it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3076448440551758 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.40it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.00it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.05it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 669486.45it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 340659.59it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 508912.99it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2451.25it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3953526020050049 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.55it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.66it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.88it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 580978.97it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 310943.49it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 493535.24it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2405.62it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.30605387687683105 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.39it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.88it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.96it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 668878.10it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 342149.86it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 510222.21it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2419.75it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3060142993927002 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 44.51it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.83it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.94it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 664350.50it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 341534.64it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 510222.21it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2405.24it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.40015149116516113 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.02it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.53it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 32.87it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 629145.60it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 322169.70it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 474151.17it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2131.25it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.3076443672180176 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.12it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.15it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 34.15it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 581897.51it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 318618.35it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 475124.79it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2549.45it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.38414669036865234 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.65it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 49.20it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.94it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 655185.00it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 353239.74it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 535408.65it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2553.40it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.2920050621032715 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 46.44it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.86it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.90it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 705414.81it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 341710.19it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 519968.02it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2537.67it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.810000e+02   0.000000e+00      0s
#      337    2.4509100e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 337 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.450909970e+03
# Building took 0.2953348159790039 seconds
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 47.85it/s]
# Loading TIFFs: 100%|██████████| 12/12 [00:00<00:00, 48.97it/s]
# 1 non-connected masks at t=0.
# 1 non-connected masks at t=6.
# 1 non-connected masks at t=9.
# 2 non-connected masks at t=10.
# 1 non-connected masks at t=11.
# Matching frames: 100%|██████████| 12/12 [00:00<00:00, 33.95it/s]
# Evaluating nodes: 100%|██████████| 351/351 [00:00<00:00, 591482.81it/s]
# Evaluating FP edges: 100%|██████████| 317/317 [00:00<00:00, 332564.87it/s]
# Evaluating FN edges: 100%|██████████| 331/331 [00:00<00:00, 506684.17it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 2568.89it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3945 rows, 7508 columns and 18607 nonzeros
# Model fingerprint: 0xee33ce73
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+04]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 32 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 3913 rows, 7476 columns, 18513 nonzeros
#
# ...
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 358124.36it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 501700.83it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2716.61it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14818978309631348 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.04it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.96it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.78it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 620612.18it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 291820.68it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 434528.42it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2762.49it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14708209037780762 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.03it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 14.33it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  9.17it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 641985.31it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 357865.42it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 510498.06it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2905.36it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.13938450813293457 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.00it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.73it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.75it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 596346.54it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 346588.15it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 441899.89it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2727.42it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14699888229370117 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.01it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.97it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.77it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 691843.96it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 354532.86it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 469571.04it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2758.46it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14728546142578125 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.02it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 14.04it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.76it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 696631.81it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 354914.21it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 498416.79it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2754.47it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.1492290496826172 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.67it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 14.29it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  9.15it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 670641.55it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 357348.64it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 516626.17it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2928.57it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.1390087604522705 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.58it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 14.60it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  9.13it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 630722.41it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 341447.31it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 507358.15it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2896.92it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14017295837402344 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.59it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 14.29it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.73it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 664005.91it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 354152.32it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 490270.30it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2787.64it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.14710354804992676 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 12.98it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.95it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.73it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 680617.28it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 363516.62it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 492220.66it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2767.56it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1427 rows, 2606 columns and 6396 nonzeros
# Model fingerprint: 0x6a11cc54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 6e+03]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1421 rows, 2600 columns, 6380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.440000e+02   0.000000e+00      0s
#      236    1.7130012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.713001160e+02
# Building took 0.1458570957183838 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 12.79it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:04<00:00, 13.52it/s]
# Matching frames: 100%|██████████| 60/60 [00:06<00:00,  8.65it/s]
# Evaluating nodes: 100%|██████████| 240/240 [00:00<00:00, 664883.06it/s]
# Evaluating FP edges: 100%|██████████| 236/236 [00:00<00:00, 355168.91it/s]
# Evaluating FN edges: 100%|██████████| 236/236 [00:00<00:00, 506061.22it/s]
# Computing candidate edges: 100%|██████████| 59/59 [00:00<00:00, 2697.24it/s]
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 783 rows, 1399 columns and 3419 nonzeros
# Model fingerprint: 0x1866d4a4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 1e+100]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 778 rows, 1394 columns, 3406 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.620000e+02   0.000000e+00      0s
#      181    5.0783279e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 181 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.078327913e+02
# Building took 0.10284900665283203 seconds
# Loading TIFFs: 100%|██████████| 60/60 [00:10<00:00,  5.48it/s]
# Loading TIFFs: 100%|██████████| 60/60 [00:10<00:00,  5.78it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
